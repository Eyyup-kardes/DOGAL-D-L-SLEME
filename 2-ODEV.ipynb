# %%
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm
tqdm.pandas()
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
from nltk import tokenize


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re
import nltk

from tqdm import trange
from nltk import tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# c:\Users\Pc\anaconda3\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
'''
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
'''

# %%
# Verilen metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# 'i' harflerinin sayısını bul
i_sayisi = metin.count('i')

# Sonucu yazdır
print(f"Metindeki toplam 'i' harfi sayısı: {i_sayisi}")
# Out:
# Metindeki toplam 'i' harfi sayısı: 224

# %%
# Verilen metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Metindeki noktaları bul
noktalar = [i for i, harf in enumerate(metin) if harf == '.']

# Noktaların sayısı
print(f"Metindeki toplam nokta sayısı: {len(noktalar)}")

# Noktaların bulunduğu indeksler
print(f"Noktaların bulunduğu indeksler: {noktalar}")
# Out:
# Metindeki toplam nokta sayısı: 46
# Noktaların bulunduğu indeksler: [101, 252, 431, 572, 596, 701, 788, 921, 1016, 1194, 1231, 1318, 1350, 1402, 1466, 1514, 1602, 1634, 1709, 1752, 1842, 1945, 2016, 2108, 2130, 2174, 2235, 2301, 2419, 2471, 2551, 2618, 2732, 2883, 2956, 3001, 3098, 3164, 3193, 3256, 3345, 3430, 3538, 3646, 3754, 3861]

# %%
# Verilen metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Olumsuzluk belirteçleri
olumsuzluk_belirtec_listesi = ["değil", "yok", "hiç", "asla", "olmaz"]

# Cümleleri ayır
cumleler = metin.split('.')

# Olumsuz cümleleri bulma
olumsuz_cumleler = [cumle for cumle in cumleler if any(olumsuzluk_belirtec in cumle for olumsuzluk_belirtec in olumsuzluk_belirtec_listesi)]

# Olumsuz cümleleri yazdır
print("Olumsuz cümleler:")
for cumle in olumsuz_cumleler:
    print(cumle.strip())
# Out:
# Olumsuz cümleler:
# Ormanın Kalbindeki Sırlar
# Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı
# Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi
# Hiçbir kötülük peşinde değilim
# Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı
# Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi
# Bu bir balık değildi
# Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu
# Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı

# %%
# Verilen metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Cümleleri ayır
cumleler = metin.split('.')

# "ve" kelimesini içeren cümleleri bulma
ve_iceren_cumleler = [cumle for cumle in cumleler if " ve " in cumle]

# "ve" kelimesini içeren cümle sayısı
ve_cumle_sayisi = len(ve_iceren_cumleler)

# Sonuçları yazdır
print(f"İçinde 've' kelimesi geçen cümle sayısı: {ve_cumle_sayisi}")
print("\nİçinde 've' kelimesi geçen cümleler:")
for cumle in ve_iceren_cumleler:
    print(cumle.strip())
# Out:
# İçinde 've' kelimesi geçen cümle sayısı: 13
#
# İçinde 've' kelimesi geçen cümleler:
# Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı
# Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu
# Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:
#
# "Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de
# Bu orman çok büyük ve her köşesi ayrı bir sır gibi
# "
#
# Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu
# Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu
# Doğa, burada yaşayan herkes için adil ve cömerttir
# Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü
# ...

# %%
# Verilen metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Noktalama işaretleri
noktalama_isaretleri = ['.', ',', ';', ':', '!', '?', '“', '”', '‘', '’']

# Noktalama işaretlerini sayma
noktalama_sayisi = sum(metin.count(isaret) for isaret in noktalama_isaretleri)

# Sonucu yazdır
print(f"Metinde kullanılan toplam noktalama işareti sayısı: {noktalama_sayisi}")
# Out:
# Metinde kullanılan toplam noktalama işareti sayısı: 104

# %%
# Verilen metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Sesli harfler listesi
sesli_harfler = "aeıioöuüAEIİOÖUÜ"

# Toplam hece sayısını bulma
hece_sayisi = sum(1 for harf in metin if harf in sesli_harfler)

# Sonucu yazdır
print(f"Metindeki toplam hece sayısı: {hece_sayisi}")
# Out:
# Metindeki toplam hece sayısı: 1356

# %%
# Metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Cümleleri böler
cumleler = metin.split('. ')

# "ceylan" kelimesinin geçtiği cümleleri bul
ceylan_cumleler = [cumle for cumle in cumleler if "ceylan" in cumle]

# Sonuçları yazdır
for c in ceylan_cumleler:
    print(c.strip() + '.')
# Out:
# Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.
#
# Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi.
# Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.
#
# Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı.
# Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:
#
# "Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de.
# Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.
#
# Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi.
# ...

# %%
# Metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Kelimeleri ayır ve en uzun kelimeyi bul
kelimeler = metin.split()
en_uzun_kelime = max(kelimeler, key=len)

# Sonucu yazdır
print(f"En uzun kelime: '{en_uzun_kelime}' - {len(en_uzun_kelime)} harfli.")
# Out:
# En uzun kelime: 'derinliklerinden' - 16 harfli.

# %%
# Metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# ? ile biten cümleleri bul
cumleler = metin.split('.')
soru_cumleleri = [cumle.strip() for cumle in cumleler if '?' in cumle]

# Sonucu yazdır
print("Metindeki '?' ile biten cümleler:")
for cümle in soru_cumleleri:
    print(cümle)
# Out:
# Metindeki '?' ile biten cümleler:
# Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:
#
# "Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de

# %%
# Metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Olumlu cümleleri bulmak için olumlu kelimeler
olumlu_kelime_listesi = ["güzel", "harika", "mutlu", "başarılı", "keyifli", "sevimli", "mükemmel", "dost", "adil", "cömert", "bilge", "güzellik"]

# Cümleleri ayır ve olumlu olanları bul
cumleler = metin.split('.')
olumlu_cumleler = [cumle.strip() for cumle in cumleler if any(kelime in cumle for kelime in olumlu_kelime_listesi)]

# Sonucu yazdır
print("Metindeki olumlu cümleler:")
for cümle in olumlu_cumleler:
    print(cümle)
# Out:
# Metindeki olumlu cümleler:
# Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı
# Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi
# Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu
# Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:
#
# "Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de
# "
#
# Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum
# Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi
# Doğa, burada yaşayan herkes için adil ve cömerttir
# Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:
#
# ...

# %%
# Metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Cümleleri ayır
cumleler = metin.split('.')

# Belirli cümleyi bul
belirli_cumle = "Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü"
bulunan_cumleler = []

for cumle in cumleler:
    if belirli_cumle in cumle:
        bulunan_cumleler.append(cumle.strip() + '.')

# Sonucu yazdır
if bulunan_cumleler:
    print("Bulunan cümle:")
    for cumle in bulunan_cumleler:
        print(cumle)
else:
    print("Belirli cümle bulunamadı.")
# Out:
# Bulunan cümle:
# "
#
# Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü.

# %%
# Metin
metin = """
Ormanın Kalbindeki Sırlar
Bir zamanlar, uzak diyarlarda, yeşilliklerin hiç bitmediği bir orman vardı. Bu orman, insanların ayak basmadığı kadar derin, rüzgârın fısıldadığı kadar sakin, ve hayvanların en güvenli yuvalarını bulduğu kadar dost canlısıydı. Ormanın her köşesi, yaşamın birer parçasıydı; devasa ağaçların gölgesinde oynayan tilkilerden, yapraklar arasında saklanan kelebeklere kadar her şey mükemmel bir denge içindeydi.

Bir sabah, küçük bir ceylan, ailesinin yanından ayrılarak ormanın daha önce hiç gitmediği bir bölümüne doğru adımlarını atmaya karar verdi. Gözlerinde merak vardı. Ağaçların gölgesinde yankılanan kuş seslerini dinleyerek, yeni maceralara atılmanın heyecanıyla doluydu. Ormanın derinliklerine doğru ilerledikçe, her şey daha da büyülü hale gelmeye başladı. Güneş ışıkları, yapraklar arasında dans ederek ceylanın yolunu aydınlatıyor, ormanın gizemli ve güzel yanını gözler önüne seriyordu.

Yol boyunca ceylan, bir su birikintisinin kenarında dinlenen yaşlı bir kaplumbağaya rastladı. Kaplumbağa, yavaş ama bilge bakışlarıyla ceylana baktı ve ona yaklaşarak sordu:

"Genç ceylan, neden bu kadar derinlere geldin? Bu orman büyüleyici olduğu kadar tehlikelidir de. Bilmediğin yerlere dikkat etmelisin."

Ceylan, nazikçe cevap verdi: "Ben sadece ormanın güzelliklerini keşfetmek istiyorum. Hiçbir kötülük peşinde değilim. Bu orman çok büyük ve her köşesi ayrı bir sır gibi."

Kaplumbağa gülümsedi ve dedi ki: "Doğru, orman sırlarla dolu. Ama unutma, her sır, doğru zamanda açığa çıkar."

Ceylan, kaplumbağanın sözlerinden etkilenmiş olsa da, keşfetme arzusundan vazgeçmedi. Daha da ilerlemeye karar verdi. Derken, birden ormanın içinde daha önce hiç görmediği bir açıklığa ulaştı. Bu açıklık, devasa bir gölün kıyısındaydı. Gölün suyu o kadar berraktı ki, yansıyan gökyüzü bile olduğundan daha parlak görünüyordu.

Ancak gölün kıyısında yalnızca suyun güzelliği değil, etrafta toplanan hayvanlar da dikkat çekiciydi. Tavşanlar, sincaplar, kuşlar ve hatta büyük bir geyik orada duruyordu. Ceylan, bu tuhaf toplaşmayı izlerken, gölün ortasında bir şeyin hareket ettiğini fark etti. Bu bir balık değildi. Gölde bir devinme, hafif bir titreme vardı. Ve birden, suyun içinden devasa bir kaplumbağa kafası çıktı. Bu, kaplumbağa tanrıçası olarak bilinen ormanın kadim varlığıydı.

Kaplumbağa tanrıçası, bütün hayvanlara bakarak konuşmaya başladı:

"Ormanın sakinleri, bu göl, tüm ormanın kalbidir. Doğa, burada yaşayan herkes için adil ve cömerttir. Ancak ormanın dengesini bozmaya çalışanlar, bu gücü karşılarında bulacaklardır."

Ceylan, kaplumbağa tanrıçasının söylediklerini dikkatle dinledi. Ormanın bu dengeye nasıl sahip olduğunu ve her canlının bu dengeyi korumak için nasıl bir rol oynadığını düşündü. Bir anda ormanın sadece ağaçlardan ve hayvanlardan ibaret olmadığını, burada yaşayan her canlının birbirine görünmeyen bağlarla bağlı olduğunu anladı.

Gün batarken, ceylan ormanın derinliklerinden geri dönmeye karar verdi. Yolda yaşlı kaplumbağa onu tekrar karşıladı. Kaplumbağa bu kez bilgece bir gülümsemeyle dedi ki:

"Ormanın sırlarını anlamışsın, genç ceylan. Unutma, doğa hepimizi korur, ancak biz de onu korumak zorundayız. Her şey birbiriyle bağlıdır."

Ceylan, kaplumbağaya teşekkür ederek ailesinin yanına döndü. Artık ormanı keşfetmek ona sadece bir macera değil, büyük bir sorumluluk gibi geliyordu. Orman, kendini ona açmıştı ve bu sırları korumak ceylanın da görevi haline gelmişti.

Ve böylece, doğanın kalbindeki sırları anlayan ceylan, bir daha asla ormandaki dengeyi bozmaya kalkışmadı. Ormanın her köşesine büyük bir saygıyla yaklaştı ve bu sayede ormanın en güvenilir sakinlerinden biri oldu.

Hikayenin Sonu
Bu hikaye, doğanın dengesi ve her canlının bu dengedeki yerini anlatan güzel bir hikayedir. Doğanın bize sunduğu güzelliklerin ve sırların, ona saygı duyduğumuz sürece açığa çıkacağı mesajını verir.
"""

# Cümleleri ayır
cumleler = metin.split('.')

# Belirli cümleyi bul
belirli_cumle = "Ceylan, kaplumbağaya teşekkür etti ve kaçtı"
bulunan_cumleler = []

for cumle in cumleler:
    if belirli_cumle in cumle:
        bulunan_cumleler.append(cumle.strip() + '.')

# Sonucu yazdır
if bulunan_cumleler:
    print("Bulunan cümle:")
    for cumle in bulunan_cumleler:
        print(cumle)
else:
    print("Belirli cümle bulunamadı.")
# Out:
# Belirli cümle bulunamadı.
